# %%
### Loading the data

# %%
import pandas as pd

us = pd.read_excel("us_housing.xlsx")
global_ = pd.read_excel("global_housing.xlsx")

# %%
### Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = us.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("US Housing Correlation Heatmap")
plt.show()

# %%
### Regression Analysis

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
from sklearn.impute import SimpleImputer
import numpy as np

# Check for NaN values
print("Number of NaN values in each column:")
print(X.isna().sum())

# Drop rows with any NaN values
X_cleaned = X.dropna()
y_cleaned = y[X_cleaned.index]

model = LinearRegression().fit(X_cleaned, y_cleaned)
print("R² score:", model.score(X_cleaned, y_cleaned))
# Out:
# Number of NaN values in each column:
# gdp                0
# mortgage_rate      3
# employment_rate    3
# dtype: int64
# R² score: 0.738697878542777
